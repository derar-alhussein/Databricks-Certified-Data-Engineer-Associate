-- %%
%sql
SELECT * FROM employees@v4

-- %%
CREATE OR REPLACE TEMP VIEW employees_view AS
SELECT * FROM employees@v4;

-- %%
SELECT * FROM employees_view;

-- %%
SET use_cached_result = false;

-- %%
DESCRIBE History employees

-- %%
SET use_cached_result = false
